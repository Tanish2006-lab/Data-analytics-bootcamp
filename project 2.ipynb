# %%
import sqlite3
conn = sqlite3.connect('shopping.db')
cursor = conn.cursor()
cursor.execute('''
CREATE TABLE IF NOT EXISTS products (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT NOT NULL,
    price REAL NOT NULL
)
''')
cursor.execute('''
CREATE TABLE IF NOT EXISTS cart (
    product_id INTEGER,
    quantity INTEGER,
    FOREIGN KEY(product_id) REFERENCES products(id)
)
''')

conn.commit()
def add_product(name, price):
    cursor.execute("INSERT INTO products (name, price) VALUES (?, ?)", (name, price))
    conn.commit()
    print(f"Product '{name}' added successfully.")
def view_products():
    cursor.execute("SELECT * FROM products")
    rows = cursor.fetchall()
    print("Available Products:")
    for row in rows:
        print(f"ID: {row[0]}, Name: {row[1]}, Price: ₹{row[2]}")
def add_to_cart(product_id, quantity):
    cursor.execute("INSERT INTO cart (product_id, quantity) VALUES (?, ?)", (product_id, quantity))
    conn.commit()
    print(f"Product ID {product_id} added to cart (Quantity: {quantity})")
def view_cart_and_bill():
    cursor.execute('''
        SELECT p.name, p.price, c.quantity, p.price * c.quantity as total
        FROM cart c
        JOIN products p ON c.product_id = p.id
    ''')
    rows = cursor.fetchall()
    if not rows:
        print("Your cart is empty.")
        return

    grand_total = 0
    print("🛒 Cart Summary:")
    for name, price, qty, total in rows:
        print(f"{name} - ₹{price} x {qty} = ₹{total}")
        grand_total += total

    print("\n💰 Total Bill: ₹", grand_total)
def clear_cart():
    cursor.execute("DELETE FROM cart")
    conn.commit()
    print("Cart cleared.")

add_product("T-shirt", 10000)
add_product("Shoes", 12000)
add_product("Cap", 2500)
view_products()

add_to_cart(1, 2)
add_to_cart(2, 1)
add_to_cart(3, 3)view_cart_and_bill()
# Out:
# Product 'T-shirt' added successfully.
# Product 'Shoes' added successfully.
# Product 'Cap' added successfully.
# Available Products:
# ID: 1, Name: T-shirt, Price: ₹500.0
# ID: 2, Name: Shoes, Price: ₹1200.0
# ID: 3, Name: Cap, Price: ₹250.0
# ID: 4, Name: T-shirt, Price: ₹500.0
# ID: 5, Name: Shoes, Price: ₹1200.0
# ID: 6, Name: Cap, Price: ₹250.0
# ID: 7, Name: T-shirt, Price: ₹500.0
# ID: 8, Name: Shoes, Price: ₹1200.0
# ID: 9, Name: Cap, Price: ₹250.0
# ID: 10, Name: T-shirt, Price: ₹500.0
# ID: 11, Name: Shoes, Price: ₹1200.0
# ID: 12, Name: Cap, Price: ₹250.0
# ID: 13, Name: T-shirt, Price: ₹10000.0
# ID: 14, Name: Shoes, Price: ₹12000.0
# ID: 15, Name: Cap, Price: ₹2500.0
# Product ID 1 added to cart (Quantity: 2)
# Product ID 2 added to cart (Quantity: 1)
# Product ID 3 added to cart (Quantity: 3)
# 🛒 Cart Summary:
# T-shirt - ₹500.0 x 2 = ₹1000.0
# Shoes - ₹1200.0 x 1 = ₹1200.0
# Cap - ₹250.0 x 3 = ₹750.0
# T-shirt - ₹500.0 x 2 = ₹1000.0
# Shoes - ₹1200.0 x 1 = ₹1200.0
# Cap - ₹250.0 x 3 = ₹750.0
# T-shirt - ₹500.0 x 2 = ₹1000.0
# Shoes - ₹1200.0 x 1 = ₹1200.0
# Cap - ₹250.0 x 3 = ₹750.0
# T-shirt - ₹500.0 x 2 = ₹1000.0
# Shoes - ₹1200.0 x 1 = ₹1200.0
# Cap - ₹250.0 x 3 = ₹750.0
# T-shirt - ₹500.0 x 2 = ₹1000.0
# Shoes - ₹1200.0 x 1 = ₹1200.0
# Cap - ₹250.0 x 3 = ₹750.0
#
# 💰 Total Bill: ₹ 14750.0
